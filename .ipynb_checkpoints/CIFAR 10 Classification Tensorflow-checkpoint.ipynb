# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pickle
import os
import numpy as np

# %%
path = os.path.join('..', 'Dataset\\CIFAR10')
os.listdir(path)
# Out:
# ['batches.meta',
#  'data_batch_1',
#  'data_batch_2',
#  'data_batch_3',
#  'data_batch_4',
#  'data_batch_5',
#  'readme.html',
#  'test_batch']

# %%
def unpickle(path):
    with open(path, 'rb') as f:
        data = pickle._Unpickler(f)
        data.encoding = 'latin1'
        d = data.load()
    return d

# %%
def one_hot_encode(data, categories):
    
    val = np.eye(categories)
    return val[data]

# %%
def data_load():
    data = [unpickle(path + '\\data_batch_{}'.format(i)) for i in range(1, 6)]
    images = np.vstack([i['data'] for i in data])
    label = np.hstack([i['labels'] for i in data])
    images = images.reshape(images.shape[0], 3, 32, 32).transpose(0, 2, 3, 1)
    
    return images, one_hot_encode(label, 10)

# %%
images, label = data_load()

# %%
def display_cifar(images, size):
     n = len(images)
     plt.figure()
     plt.gca().set_axis_off()
     im = np.vstack([np.hstack([images[np.random.choice(n)] for i in range(size)])
     for i in range(size)])
     plt.imshow(im)
     plt.show()

# %%
display_cifar(images, 5)

# %%
def W_initial(shape, mu = 0, std = 1):
    return tf.Variable(tf.random.normal(shape, mu, std))

def b_initial(shape):
    return tf.Variable(tf.random.normal(shape))

def conv2D(x,w_shape, b_shape):
    kernel = W_initial(shape) ## Have to assign later
    bias = b_initial([]) ## Have to assign later
    conv = tf.nn.conv2d(x, W, padding = 'same', strides=[1,1,1,1])
    return tf.nn.relu(conv + bias)

def max_pool_2x2(x):
    
    return tf.nn.max_pool(x, ksize = [1, 2, 2, 1], strides=[1, 2, 2, 1], padding = 'same')

def fully_connected_layer(x, w_shape, b_shape):
    
    W = W_initial(shape) ## Have to assign later
    b = b_initial([])
